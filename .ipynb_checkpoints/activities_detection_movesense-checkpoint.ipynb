# %% [markdown]
# # Motion activities detection
#
# The goal is to detect motion activities. See the lab description for more information.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the data

# %%
def read_data(path: Path) -> pd.DataFrame:
    """
    Read the CSVs from the given path.
    
    Set a multiindex with the record number and the timestamp.
    
    Parameters
    ----------
    path : Path
        Path containing the CSV files.
    
    Returns
    -------
    pd.DataFrame
        DataFrame with all the CSVs.
    """
    return pd.concat([
        (pd.read_csv(p, index_col=False)
         .assign(record=i)
         .rename(columns={'Timestamp (ms)': 'ts', 'X: (m/s^2)': 'x', 'Y: (m/s^2)': 'y', 'Z: (m/s^2)': 'z'})
         .set_index(['record', 'ts'])
         .assign(norm=lambda x: np.linalg.norm(x.values, axis=1))
         ) for i, p in enumerate(path)])

# %%
# Get all the csv from the folders and load them in DataFrames.
data_path = Path('data')
jump_paths         = list((data_path / 'jump').glob('*.csv'))
rest_paths         = list((data_path / 'rest').glob('*.csv'))
walk_paths         = list((data_path / 'walk').glob('*.csv'))
pushup_paths       = list((data_path / 'pushup').glob('*.csv'))
jumping_jack_paths = list((data_path / 'jumping_jack').glob('*.csv'))
noise_paths        = list((data_path / 'noise').glob('*.csv'))

# %%
jumps = read_data(jump_paths)
rests = read_data(rest_paths)
walks = read_data(walk_paths)
pushup = read_data(pushup_paths)
jumping_jack = read_data(jumping_jack_paths)
noise = read_data(noise_paths)

# %%
print(pushup)
# Out:
#                        x         y         z       norm
# record ts
# 0      30119   -8.774794  0.988271 -5.762123  10.543991
#        30199  -10.772872  2.163189 -6.492720  12.762820
#        30279  -12.574732  1.289778 -8.217246  15.076821
#        30359  -12.452694  0.717900 -8.511574  15.100724
#        30439  -11.933433  0.335007 -7.762594  14.239976
# ...                  ...       ...       ...        ...
# 4      129264  -7.104544 -1.119881 -3.866940   8.165899
#        129344  -5.771694 -2.286400 -3.407501   7.081747
#        129423  -5.376864 -1.777931 -2.677664   6.264311
#        129503  -7.102151 -3.950691 -3.589362   8.884370
#        129583  -7.719522 -2.263691 -4.783423   9.359298
#
# [613 rows x 4 columns]

# %% [markdown]
# ## Visualization of the norm of the accelerations

# %%
def plot_data(df: pd.DataFrame, col: str = 'norm', title: str = 'Plot of norm') -> plt.axes:
    """
    Plot the given column of the DataFrame.
    """
    ax = df[col].plot(figsize=(15, 8))
    ax.set_title(title, fontsize=14)
    # Style.
    # Remove border on the top and right.
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    # Set alpha on remaining borders.
    ax.spines['left'].set_alpha(0.4)
    ax.spines['bottom'].set_alpha(0.4)

    # Only show ticks on the left and bottom spines
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    #MODIFED: y axe is fixed
    plt.ylim([0,80])
    # Style of ticks.
    plt.xticks(fontsize=10, alpha=0.7)
    plt.yticks(fontsize=10, alpha=0.7)
    
    return ax

# %%
plot_data(jumps, title='Norm of acceleration when jumping')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration when jumping'}, xlabel='record,ts'>

# %%
jumps.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(jumps));
print("\nmoyenne:\n", np.mean(jumps));
# Out:
# variance:
#  x       105.163262
# y        36.085061
# z         3.895544
# norm     70.742848
# dtype: float64
#
# moyenne:
#  x        2.821327
# y       -5.092196
# z        1.836568
# norm    10.567135
# dtype: float64

# %%
plot_data(rests, title='Norm of acceleration when resting')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration when resting'}, xlabel='record,ts'>

# %%
rests.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(rests));
print("\nmoyenne:\n", np.mean(rests));
# Out:
# variance:
#  x       0.217790
# y       0.006921
# z       0.029805
# norm    0.003648
# dtype: float64
#
# moyenne:
#  x       -1.665612
# y       -9.512222
# z        2.624224
# norm    10.019683
# dtype: float64

# %%
plot_data(walks, title='Norm of acceleration when walking')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration when walking'}, xlabel='record,ts'>

# %%
walks.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(walks));
print("\nmoyenne:\n", np.mean(walks));
# Out:
# variance:
#  x       99.899007
# y       41.139506
# z        4.050281
# norm    71.947886
# dtype: float64
#
# moyenne:
#  x        3.954753
# y       -5.032246
# z        1.508464
# norm    10.787954
# dtype: float64

# %%
plot_data(pushup, title='Norm of acceleration when doing pushup')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration when doing pushup'}, xlabel='record,ts'>

# %%
pushup.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(pushup));
print("\nmoyenne:\n", np.mean(pushup));
# Out:
# variance:
#  x        9.893432
# y        2.821258
# z        3.695995
# norm    10.803612
# dtype: float64
#
# moyenne:
#  x       -8.499003
# y       -0.656957
# z       -4.708065
# norm    10.021856
# dtype: float64

# %%
plot_data(jumping_jack, title='Norm of acceleration when doing juming jack')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration when doing juming jack'}, xlabel='record,ts'>

# %%
jumping_jack.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(jumping_jack));
print("\nmoyenne:\n", np.mean(jumping_jack));
# Out:
# variance:
#  x         7.363611
# y       442.688242
# z        17.590515
# norm    383.777078
# dtype: float64
#
# moyenne:
#  x        0.686059
# y      -10.366153
# z       -1.727298
# norm    13.956241
# dtype: float64

# %%
plot_data(noise, title='Norm of acceleration of the noise')
# Out:
# <AxesSubplot:title={'center':'Norm of acceleration of the noise'}, xlabel='record,ts'>

# %%
noise.boxplot()
# Out:
# <AxesSubplot:>

# %%
print("variance:\n", np.var(noise));
print("\nmoyenne:\n", np.mean(noise));
# Out:
# variance:
#  x       0.978507
# y       0.000516
# z       0.001010
# norm    0.002362
# dtype: float64
#
# moyenne:
#  x       -0.943595
# y        0.176125
# z        9.925314
# norm    10.020525
# dtype: float64

# %% [markdown]
# ## Activities detection

# %% [markdown]
# ### Questions
#
# #### 1) What characteristics of the MoseSense sensor are important to know when performing a recording ? What are the "by default" settings you are using right now ?
#
# Les exemples fournis par ce notebook utilise l'accéleration linéaire, c'est un indicateur optimal car il enregistre les mouvements (de type saut, pompe, etc...) bien mieux que l'acceleration angulaire
#
# #### 2) How noisy is the data captured by the MoveSense sensor ?
# On peut le voir dans le graphique noise, nous l'avons enregistrer en posant le capteur sans le toucher. On peut voir quelques pics qui correspondent au bruit du capteur et aussi à quelques vibrations externes. Le bruit est cepandant très faible quand il est comparer aux autres graphiques.
#
# #### 3) How variable are the recordings you made for a given activity ? How variable is the feature you computed to characterize a given activity ?
#
# Cela dépend beaucoup de l'activité en elle-même, par exemple un saut développe beaucoup plus d'accélération linéaire que des pompes.
# #### 4) Is it always possible to differentiate various activities by computing a feature of the corresponding data ? If not, why not combining multiple features (e.g., median, range, standard deviation) and defining a rule (or a set of rules) based on them ?
# On voit que pour certains cas comme sauter et marcher les graphiques sont visiblement différents mais la moyenne est la variance sont prèsque similaire. Mais si on compare les autres activités entres elles on obtient des moyennes et des variances très différentes. On pourrait imaginer faire un tableaux de ces indicateurs puis par exemple utiliser un algorithme comme knn pour prédire nos activités. Ce knn aurait du mal avec certaines activité comme les sauts et marcher mais serait quand même assez efficace.
#
# #### 5) What other features can be computed to characterize a set of measurements like the ones captured using the MoveSense during a particular activity ?
# L'accélération angulaire peut aussi être captée. elle aurait pu par exemple permettre de mieux différencier entre les sauts et la marche.
#
# #### 6) For a cyclic activity like walking, can you identify a periodic pattern in the data ?
# Oui on voit très clairement un pattern ce former. Il est en revanche moins visible pour par exemple les pompes. Si on arrive à isolé le contour du patter et utiliser un algorithme permettant de le reconnaitre, il pourrait être plus facile de reconnaitre certaines activités
#
# #### 7) Did you observe that the sensor has to be worn in the same way during an experiment ? (e.g., you cannot turn it upside down for instance ?) why ? by the way, did you notice the sensing of the acceleration caused by gravity and how it perturbs your data ?

# %%
# TODO
